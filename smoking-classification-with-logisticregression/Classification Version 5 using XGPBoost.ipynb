# %% [markdown]
# # Smoking classification
# * ID : index
# * gender
# * age : 5-years gap
# * height(cm)
# * weight(kg)
# * waist(cm) : Длинна окружности талии
# * eyesight(left) - зренние правого глаза
# * eyesight(right) - зренние левого глаза
# * hearing(left) - слух левого уха
# * hearing(right) - слух правого уха
# * systolic : Blood pressure - кровяное давление
# * relaxation : Blood pressure - давление в спокойствие
# * fasting blood sugar - уровень сахара в крови на тощак
# * Cholesterol : total - холестерин всего
# * triglyceride -
# * HDL : cholesterol type
# * LDL : cholesterol type
# * hemoglobin - гемоглобин
# * Urine protein - белок мочи
# * serum creatinine - креатин в сыворотке крови
# * AST : glutamic oxaloacetic transaminase type
# * ALT : glutamic oxaloacetic transaminase type
# * Gtp : γ-GTP
# * oral : Oral Examination status
# * dental caries - зубной кариес
# * tartar : tartar status
# * smoking : 0 or 1

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (1.7.5)
# Requirement already satisfied: numpy in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (1.24.2)
# Requirement already satisfied: scipy in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (1.10.1)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import fisher_exact

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('smoking_train.csv')
df.head()
# Out:
#    ID gender   age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   2      M  55.0         170        60.0       80.0             0.8
# 1   3      M  40.0         165        70.0       88.0             1.5
# 2   4      F  40.0         155        60.0       86.0             1.0
# 3   5      M  30.0         180        75.0       85.0             1.2
# 4   6      M  40.0         160        60.0       85.5             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              0.8            1.0             1.0  ...        15.8
# 1              1.5            1.0             1.0  ...        14.7
# 2              1.0            1.0             1.0  ...        12.5
# 3              1.2            1.0             1.0  ...        16.2
# 4              1.0            1.0             1.0  ...        17.0
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               1.0  21.0  16.0  22.0     Y              0
# 1            1.0               1.0  19.0  26.0  18.0     Y              0
# 2            1.0               0.6  16.0  14.0  22.0     Y              0
# 3            1.0               1.2  18.0  27.0  33.0     Y              0
# 4            1.0               0.7  21.0  27.0  39.0     Y              1
#
#    tartar  smoking
# 0       N      yes
# 1       Y       no
# 2       N       no
# 3       Y       no
# 4       Y      yes
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (44554, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44554 entries, 0 to 44553
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   44554 non-null  int64
#  1   gender               44554 non-null  object
#  2   age                  44114 non-null  float64
#  3   height(cm)           44554 non-null  int64
#  4   weight(kg)           44510 non-null  float64
#  5   waist(cm)            44554 non-null  float64
#  6   eyesight(left)       44554 non-null  float64
#  7   eyesight(right)      44554 non-null  float64
#  8   hearing(left)        44554 non-null  float64
#  9   hearing(right)       44554 non-null  float64
#  10  systolic             44554 non-null  float64
#  11  relaxation           44554 non-null  float64
#  12  fasting blood sugar  44554 non-null  float64
#  13  Cholesterol          44554 non-null  float64
#  14  triglyceride         44554 non-null  float64
#  15  HDL                  44554 non-null  float64
#  16  LDL                  44554 non-null  float64
#  17  hemoglobin           44554 non-null  float64
#  18  Urine protein        44554 non-null  float64
#  19  serum creatinine     44554 non-null  float64
#  20  AST                  44554 non-null  float64
#  21  ALT                  44554 non-null  float64
#  22  Gtp                  44554 non-null  float64
#  23  oral                 44554 non-null  object
#  24  dental caries        44554 non-null  int64
#  25  tartar               44554 non-null  object
#  26  smoking              44554 non-null  object
# dtypes: float64(20), int64(3), object(4)
# memory usage: 9.2+ MB

# %%
print("Переменнная : Количество пропусков")
for i in df.columns:
    if (df[i].isna().any()):
        print(f'{i} : {df[i].isna().sum()}')
# Out:
# Переменнная : Количество пропусков
# age : 440
# weight(kg) : 44

# %% [markdown]
# ## Работа с категориальными переменными

# %%
df.head()
# Out:
#    ID gender   age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   2      M  55.0         170        60.0       80.0             0.8
# 1   3      M  40.0         165        70.0       88.0             1.5
# 2   4      F  40.0         155        60.0       86.0             1.0
# 3   5      M  30.0         180        75.0       85.0             1.2
# 4   6      M  40.0         160        60.0       85.5             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              0.8            1.0             1.0  ...        15.8
# 1              1.5            1.0             1.0  ...        14.7
# 2              1.0            1.0             1.0  ...        12.5
# 3              1.2            1.0             1.0  ...        16.2
# 4              1.0            1.0             1.0  ...        17.0
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               1.0  21.0  16.0  22.0     Y              0
# 1            1.0               1.0  19.0  26.0  18.0     Y              0
# 2            1.0               0.6  16.0  14.0  22.0     Y              0
# 3            1.0               1.2  18.0  27.0  33.0     Y              0
# 4            1.0               0.7  21.0  27.0  39.0     Y              1
#
#    tartar  smoking
# 0       N      yes
# 1       Y       no
# 2       N       no
# 3       Y       no
# 4       Y      yes
#
# [5 rows x 27 columns]

# %%
df['gender'].value_counts()
# Out:
# M    28372
# F    16182
# Name: gender, dtype: int64

# %%
df['gender'] = [0 if (i == 'F') else 1 for i in df['gender']]
df['gender'].value_counts()
# Out:
# 1    28372
# 0    16182
# Name: gender, dtype: int64

# %%
df['oral'] = [0 if (i == 'Y') else 1 for i in df['oral']]
df['oral'].value_counts()
# Out:
# 0    44554
# Name: oral, dtype: int64

# %%
df['tartar'].value_counts()
# Out:
# Y    24785
# N    19769
# Name: tartar, dtype: int64

# %%
df['tartar'] = [0 if (i == 'Y') else 1 for i in df['tartar']]
df['smoking'].value_counts()
# Out:
# no     28170
# yes    16384
# Name: smoking, dtype: int64

# %%
df['smoking'] = [0 if (i == 'no') else 1 for i in df['smoking']]
df['smoking'].value_counts()
# Out:
# 0    28170
# 1    16384
# Name: smoking, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44554 entries, 0 to 44553
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   44554 non-null  int64
#  1   gender               44554 non-null  int64
#  2   age                  44114 non-null  float64
#  3   height(cm)           44554 non-null  int64
#  4   weight(kg)           44510 non-null  float64
#  5   waist(cm)            44554 non-null  float64
#  6   eyesight(left)       44554 non-null  float64
#  7   eyesight(right)      44554 non-null  float64
#  8   hearing(left)        44554 non-null  float64
#  9   hearing(right)       44554 non-null  float64
#  10  systolic             44554 non-null  float64
#  11  relaxation           44554 non-null  float64
#  12  fasting blood sugar  44554 non-null  float64
#  13  Cholesterol          44554 non-null  float64
#  14  triglyceride         44554 non-null  float64
#  15  HDL                  44554 non-null  float64
#  16  LDL                  44554 non-null  float64
#  17  hemoglobin           44554 non-null  float64
#  18  Urine protein        44554 non-null  float64
#  19  serum creatinine     44554 non-null  float64
#  20  AST                  44554 non-null  float64
#  21  ALT                  44554 non-null  float64
#  22  Gtp                  44554 non-null  float64
#  23  oral                 44554 non-null  int64
#  24  dental caries        44554 non-null  int64
#  25  tartar               44554 non-null  int64
#  26  smoking              44554 non-null  int64
# dtypes: float64(20), int64(7)
# memory usage: 9.2 MB

# %% [markdown]
# ## EDA

# %%
df['gender'].value_counts().plot.pie(autopct='%1.3f%%', colors=['pink', 'white'])
# Out:
# <Axes: ylabel='gender'>

# %%
df['smoking'].value_counts().plot.pie(autopct='%1.3f%%', colors=['pink', 'white'])
# Out:
# <Axes: ylabel='smoking'>

# %%
keys = list(df.columns)

fig, axs = plt.subplots(nrows=9, ncols=3, figsize=(16, 16))
fig.subplots_adjust(hspace=1, wspace=1)
for i, col in enumerate(df.columns):
    key = col
    row, col = divmod(i, 3)
    axs[row, col].hist(df[key], density=True, bins=23, color='pink')
    axs[row, col].set_title(key)

plt.show()

# %% [markdown]
# ## Работа с пропусками

# %%
df.isna().any()
# Out:
# ID                     False
# gender                 False
# age                     True
# height(cm)             False
# weight(kg)              True
# waist(cm)              False
# eyesight(left)         False
# eyesight(right)        False
# hearing(left)          False
# hearing(right)         False
# systolic               False
# relaxation             False
# fasting blood sugar    False
# Cholesterol            False
# triglyceride           False
# HDL                    False
# LDL                    False
# hemoglobin             False
# Urine protein          False
# serum creatinine       False
# AST                    False
# ALT                    False
# Gtp                    False
# oral                   False
# dental caries          False
# tartar                 False
# smoking                False
# dtype: bool

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['weight(kg)'] = df['weight(kg)'].fillna(df['weight(kg)'].mean())

# %%
df.isna().any()
# Out:
# ID                     False
# gender                 False
# age                    False
# height(cm)             False
# weight(kg)             False
# waist(cm)              False
# eyesight(left)         False
# eyesight(right)        False
# hearing(left)          False
# hearing(right)         False
# systolic               False
# relaxation             False
# fasting blood sugar    False
# Cholesterol            False
# triglyceride           False
# HDL                    False
# LDL                    False
# hemoglobin             False
# Urine protein          False
# serum creatinine       False
# AST                    False
# ALT                    False
# Gtp                    False
# oral                   False
# dental caries          False
# tartar                 False
# smoking                False
# dtype: bool

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = df.drop(['smoking', 'ID'], axis=1)
y = df[['smoking']]

# %%
scaler = StandardScaler()

# %%
std = StandardScaler()

X_std = std.fit_transform(x)

X_std = pd.DataFrame(X_std, columns=x.columns)
X_std
# Out:
#          gender       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      0.755216  0.898022    0.580744   -0.458239  -0.220828       -0.440215
# 1      0.755216 -0.349103    0.037847    0.321671   0.641678        1.013009
# 2     -1.324125 -0.349103   -1.047946   -0.458239   0.426052       -0.025008
# 3      0.755216 -1.180520    1.666537    0.711626   0.318238        0.390199
# 4      0.755216 -0.349103   -0.505049   -0.458239   0.372145       -0.025008
# ...         ...       ...         ...         ...        ...             ...
# 44549 -1.324125  1.313730   -1.590842   -1.238149  -0.759894       -0.025008
# 44550 -1.324125  0.066605   -0.505049   -1.238149  -1.298960        0.390199
# 44551 -1.324125  0.898022   -0.505049   -1.238149  -1.460680       -0.025008
# 44552  0.755216  1.313730    0.037847   -0.458239  -0.436454       -0.440215
# 44553  0.755216  0.898022   -0.505049   -0.068284   0.318238       -0.232612
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0            -0.423733       -0.16386       -0.164653  1.208179  ...
# 1             0.998673       -0.16386       -0.164653 -1.571897  ...
# 2            -0.017331       -0.16386       -0.164653 -0.108699  ...
# 3             0.389071       -0.16386       -0.164653  0.476580  ...
# 4            -0.017331       -0.16386       -0.164653 -0.401338  ...
# ...                ...            ...             ...       ...  ...
# 44549         0.389071       -0.16386       -0.164653 -1.425577  ...
# 44550         0.389071       -0.16386       -0.164653 -1.498737  ...
# 44551         0.389071       -0.16386       -0.164653 -0.328178  ...
# 44552        -0.017331       -0.16386       -0.164653  0.842380  ...
# 44553        -0.626933       -0.16386       -0.164653  0.183941  ...
#
#             LDL  hemoglobin  Urine protein  serum creatinine       AST  \
# 0      0.874419    0.752820      -0.215708          0.514185 -0.269763
# 1      2.692977    0.048630      -0.215708          0.514185 -0.373693
# 2     -0.192468   -1.359750      -0.215708         -1.292804 -0.529587
# 3      0.340976    1.008889      -0.215708          1.417680 -0.425657
# 4      1.019904    1.521028      -0.215708         -0.841057 -0.269763
# ...         ...         ...            ...               ...       ...
# 44549  0.025759   -1.295733      -0.215708         -0.389309 -0.009938
# 44550 -0.871396   -0.399491      -0.215708          0.062438 -0.321728
# 44551 -1.259355   -1.423768      -0.215708         -1.744552 -0.477622
# 44552  0.753182   -0.143422      -0.215708         -0.841057 -0.321728
# 44553  0.850172    0.240682      -0.215708         -0.389309 -0.009938
#
#             ALT       Gtp  oral  dental caries    tartar
# 0     -0.341084 -0.355909   0.0      -0.520517  1.119701
# 1     -0.034033 -0.434923   0.0      -0.520517 -0.893095
# 2     -0.402494 -0.355909   0.0      -0.520517  1.119701
# 3     -0.003328 -0.138619   0.0      -0.520517 -0.893095
# 4     -0.003328 -0.020098   0.0       1.921167 -0.893095
# ...         ...       ...   ...            ...       ...
# 44549 -0.187559 -0.513938   0.0      -0.520517 -0.893095
# 44550 -0.463905 -0.513938   0.0      -0.520517 -0.893095
# 44551 -0.494610 -0.553445   0.0      -0.520517  1.119701
# 44552 -0.248969 -0.434923   0.0      -0.520517  1.119701
# 44553  0.058082  0.019410   0.0      -0.520517 -0.893095
#
# [44554 rows x 25 columns]

# %% [markdown]
# ## Logistic Regression

# %%
# !pip install catboost
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: catboost in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (1.1.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (1.10.1)
# Requirement already satisfied: six in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: graphviz in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: plotly in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (5.14.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from catboost) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\никита\appdata\local\programs\python\python310\lib\site-packages (from plotly->catboost) (8.2.2)

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# %%
x_train, x_test, y_train, y_test = train_test_split(X_std,y, test_size=0.2, stratify=y, random_state=2)

# %%
model = xgb.XGBClassifier()

# %%
model.fit(x_train,np.array(y_train).ravel())
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)
training_data_accuracy
# Out:
# 0.8741407850068738

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)
test_data_accuracy
# Out:
# 0.7825159914712153

# %%
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, x_test_prediction)
cnf_matrix
# Out:
# array([[4599, 1035],
#        [ 903, 2374]], dtype=int64)

# %% [markdown]
# ## Test data

# %%
df = pd.read_csv('smoking_test.csv')
ID = df['ID']
df.drop(['ID'], axis=1, inplace=True)
df
# Out:
#       gender   age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0          M  40.0         180        75.0       85.0             1.0
# 1          M  25.0         180        75.0       83.8             0.8
# 2          F  50.0         155        65.0       86.3             0.3
# 3          F  40.0         155        45.0       74.0             1.2
# 4          M  30.0         175        70.0       79.0             0.8
# ...      ...   ...         ...         ...        ...             ...
# 11133      F  50.0         160        55.0       66.2             0.6
# 11134      M  30.0         165        65.0       76.0             1.0
# 11135      F  70.0         145        50.0       81.0             0.8
# 11136      M  40.0         175        80.0       82.2             0.7
# 11137      M  60.0         170        75.0       93.0             0.9
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...    LDL  \
# 0                  1.2            1.0             1.0     128.0  ...  145.0
# 1                  1.2            1.0             1.0     116.0  ...   99.0
# 2                  1.2            1.0             1.0     101.0  ...  120.0
# 3                  1.0            1.0             1.0     104.0  ...  105.0
# 4                  1.2            1.0             1.0     119.0  ...   57.0
# ...                ...            ...             ...       ...  ...    ...
# 11133              0.4            1.0             1.0     118.0  ...  178.0
# 11134              1.5            1.0             1.0     130.0  ...  147.0
# 11135              0.9            1.0             1.0     120.0  ...   80.0
# 11136              0.5            1.0             1.0     130.0  ...  110.0
# 11137              1.0            1.0             1.0     125.0  ...  149.0
#
#        hemoglobin  Urine protein  serum creatinine   AST   ALT   Gtp  oral  \
# 0            14.5            1.0               1.0  17.0  18.0  30.0     Y
# 1            15.3            1.0               0.9  18.0  14.0  22.0     Y
# 2            13.4            1.0               0.7  19.0  21.0  13.0     Y
# 3            13.6            1.0               0.6  18.0  16.0  16.0     Y
# 4            16.6            1.0               0.9  18.0  11.0  22.0     Y
# ...           ...            ...               ...   ...   ...   ...   ...
# 11133        12.5            1.0               0.8  22.0  17.0  16.0     Y
# 11134        14.9            1.0               1.1  32.0  31.0  19.0     Y
# 11135        14.9            1.0               0.7  36.0  32.0  19.0     Y
# 11136        18.0            1.0               1.2  36.0  52.0  71.0     Y
# 11137        16.0            1.0               0.9  23.0  19.0  16.0     Y
#
#        dental caries  tartar
# 0                  0       N
# 1                  0       Y
# 2                  0       N
# 3                  0       Y
# 4                  0       N
# ...              ...     ...
# 11133              0       N
# 11134              0       Y
# 11135              0       N
# 11136              1       Y
# 11137              0       N
#
# [11138 rows x 25 columns]

# %%
df.isna().any()
# Out:
# gender                 False
# age                     True
# height(cm)             False
# weight(kg)              True
# waist(cm)              False
# eyesight(left)         False
# eyesight(right)        False
# hearing(left)          False
# hearing(right)         False
# systolic               False
# relaxation             False
# fasting blood sugar    False
# Cholesterol            False
# triglyceride           False
# HDL                    False
# LDL                    False
# hemoglobin             False
# Urine protein          False
# serum creatinine       False
# AST                    False
# ALT                    False
# Gtp                    False
# oral                   False
# dental caries          False
# tartar                 False
# dtype: bool

# %% [markdown]
# ## Обработаем категориальные переменные

# %%
df['gender'] = [0 if (i == 'F') else 1 for i in df['gender']]
df['gender'].value_counts()
# Out:
# 1    7029
# 0    4109
# Name: gender, dtype: int64

# %%
df['oral'] = [0 if (i == 'Y') else 1 for i in df['oral']]
df['oral'].value_counts()
# Out:
# 0    11138
# Name: oral, dtype: int64

# %%
df['tartar'] = [0 if (i == 'Y') else 1 for i in df['tartar']]
df['tartar'].value_counts()
# Out:
# 0    6155
# 1    4983
# Name: tartar, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11138 entries, 0 to 11137
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               11138 non-null  int64
#  1   age                  11021 non-null  float64
#  2   height(cm)           11138 non-null  int64
#  3   weight(kg)           11126 non-null  float64
#  4   waist(cm)            11138 non-null  float64
#  5   eyesight(left)       11138 non-null  float64
#  6   eyesight(right)      11138 non-null  float64
#  7   hearing(left)        11138 non-null  float64
#  8   hearing(right)       11138 non-null  float64
#  9   systolic             11138 non-null  float64
#  10  relaxation           11138 non-null  float64
#  11  fasting blood sugar  11138 non-null  float64
#  12  Cholesterol          11138 non-null  float64
#  13  triglyceride         11138 non-null  float64
#  14  HDL                  11138 non-null  float64
#  15  LDL                  11138 non-null  float64
#  16  hemoglobin           11138 non-null  float64
#  17  Urine protein        11138 non-null  float64
#  18  serum creatinine     11138 non-null  float64
#  19  AST                  11138 non-null  float64
#  20  ALT                  11138 non-null  float64
#  21  Gtp                  11138 non-null  float64
#  22  oral                 11138 non-null  int64
#  23  dental caries        11138 non-null  int64
#  24  tartar               11138 non-null  int64
# dtypes: float64(20), int64(5)
# memory usage: 2.1 MB

# %% [markdown]
# ## Уберем пропуски

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['weight(kg)'] = df['weight(kg)'].fillna(df['weight(kg)'].mean())

# %%
df.isna().any().sum()
# Out:
# 0

# %% [markdown]
# ## Standard Scaler

# %%
scaler = StandardScaler()

# %%
std = StandardScaler()

X_std = std.fit_transform(df)

X_std = pd.DataFrame(X_std, columns=df.columns)
X_std
# Out:
#          gender       age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      0.764577 -0.346538    1.681742    0.717184   0.319423       -0.029446
# 1      0.764577 -1.600653    1.681742    0.717184   0.189966       -0.423877
# 2     -1.307913  0.489538   -1.055623   -0.064764   0.459668       -1.409954
# 3     -1.307913 -0.346538   -1.055623   -1.628660  -0.867264        0.364985
# 4      0.764577 -1.182615    1.134269    0.326210  -0.327861       -0.423877
# ...         ...       ...         ...         ...        ...             ...
# 11133 -1.307913  0.489538   -0.508150   -0.846712  -1.708733       -0.818308
# 11134  0.764577 -1.182615    0.039323   -0.064764  -0.651503       -0.029446
# 11135 -1.307913  2.161691   -2.150569   -1.237686  -0.112100       -0.423877
# 11136  0.764577 -0.346538    1.134269    1.108158   0.017357       -0.621092
# 11137  0.764577  1.325615    0.586796    0.717184   1.182468       -0.226661
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0             0.427628      -0.154601       -0.160585  0.472254  ...
# 1             0.427628      -0.154601       -0.160585 -0.403373  ...
# 2             0.427628      -0.154601       -0.160585 -1.497906  ...
# 3            -0.006727      -0.154601       -0.160585 -1.278999  ...
# 4             0.427628      -0.154601       -0.160585 -0.184466  ...
# ...                ...            ...             ...       ...  ...
# 11133        -1.309792      -0.154601       -0.160585 -0.257435  ...
# 11134         1.079160      -0.154601       -0.160585  0.618191  ...
# 11135        -0.223905      -0.154601       -0.160585 -0.111497  ...
# 11136        -1.092615      -0.154601       -0.160585  0.618191  ...
# 11137        -0.006727      -0.154601       -0.160585  0.253347  ...
#
#             LDL  hemoglobin  Urine protein  serum creatinine       AST  \
# 0      0.755010   -0.074213      -0.214233          0.522287 -0.462219
# 1     -0.405454    0.434026      -0.214233          0.072141 -0.411702
# 2      0.124323   -0.773043      -0.214233         -0.828150 -0.361184
# 3     -0.254089   -0.645983      -0.214233         -1.278295 -0.411702
# 4     -1.465009    1.259916      -0.214233          0.072141 -0.411702
# ...         ...         ...            ...               ...       ...
# 11133  1.587517   -1.344813      -0.214233         -0.378004 -0.209631
# 11134  0.805465    0.179907      -0.214233          0.972432  0.295545
# 11135 -0.884776    0.179907      -0.214233         -0.828150  0.497615
# 11136 -0.127952    2.149336      -0.214233          1.422578  0.497615
# 11137  0.855920    0.878736      -0.214233          0.072141 -0.159114
#
#             ALT       Gtp  oral  dental caries    tartar
# 0     -0.374331 -0.198057   0.0      -0.521716  1.111395
# 1     -0.545519 -0.361549   0.0      -0.521716 -0.899770
# 2     -0.245939 -0.545478   0.0      -0.521716  1.111395
# 3     -0.459925 -0.484169   0.0      -0.521716 -0.899770
# 4     -0.673910 -0.361549   0.0      -0.521716  1.111395
# ...         ...       ...   ...            ...       ...
# 11133 -0.417128 -0.484169   0.0      -0.521716  1.111395
# 11134  0.182032 -0.422859   0.0      -0.521716 -0.899770
# 11135  0.224829 -0.422859   0.0      -0.521716  1.111395
# 11136  1.080771  0.639841   0.0       1.916753 -0.899770
# 11137 -0.331533 -0.484169   0.0      -0.521716  1.111395
#
# [11138 rows x 25 columns]

# %%
y_pred = model.predict(X_std)
ans_df = pd.DataFrame()
ans_df['ID'] = ID
ans_df['smoking'] = y_pred
ans_df['smoking'] = ['yes' if(i == 1) else 'no' for i in ans_df['smoking']]

ans_df.to_csv('result.csv', index=False)

ans_df['smoking'].value_counts()
# Out:
# no     6871
# yes    4267
# Name: smoking, dtype: int64
